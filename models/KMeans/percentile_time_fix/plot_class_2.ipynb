# %%
import os
import pandas as pd
import joblib
import seaborn as sns
from matplotlib import pyplot as plt

# %%
with open(os.path.join('../../KMeans/output/class_time_2_smote.parquet'), 'rb') as f:
    df_class_2_smote = joblib.load(f)

# %%
x = df_class_2_smote['f1_smote_macro']

# %%
y = df_class_2_smote['time01'].dt.total_seconds() / 3600

# %%
sns.set_theme(style="whitegrid")

# %%
sns.displot(df_class_2_smote, x='accuracy', kde=True)

# %%
sns.displot(df_class_2_smote, x='accuracy_smote', kde=True)

# %%
sns.displot(df_class_2_smote, x='f1_macro', kde=True)

# %%
sns.displot(df_class_2_smote, x='f1_smote_macro', kde=True)

# %%
sns.displot(df_class_2_smote, x='roc_auc_macro', kde=True)

# %%
sns.residplot(x=x, y=y, lowess=True, color="g")
# Out:
# <Axes: xlabel='f1_smote_macro', ylabel='time01'>

# %%
g = sns.PairGrid(df_class_2_smote)
g.map(sns.scatterplot)

# %%
# g.savefig("seaborn_plot.jpg", dpi=300)

# %% [markdown]
# Class time 3

# %%
with open(os.path.join('../../KMeans/output/class_time_3_smote_new.parquet'), 'rb') as f:
    df_class_3_smote = joblib.load(f)

# %%
x_time_3 = df_class_3_smote['accuracy']

# %%
y_time_3 = df_class_3_smote['time12']

# %%
sns.displot(df_class_3_smote, x='accuracy', kde=True)

# %%
sns.displot(df_class_3_smote, x='accuracy_smote', kde=True)

# %%
sns.displot(df_class_3_smote, x='f1_macro', kde=True)

# %%
sns.displot(df_class_3_smote, x='f1_smote', kde=True)

# %%
sns.displot(df_class_3_smote, x='roc_auc_smote', kde=True)

# %%
c3 = sns.PairGrid(df_class_3_smote)
c3.map(sns.scatterplot)

# %%
c3.savefig("seaborn_plot_3.jpg", dpi=300)

# %%
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import axes3d

ax = plt.figure().add_subplot(projection='3d')

# %%
X, Y, Z = axes3d.get_test_data(0.05)

# %%
X
# Out:
# array([[-30. , -29.5, -29. , ...,  28.5,  29. ,  29.5],
#        [-30. , -29.5, -29. , ...,  28.5,  29. ,  29.5],
#        [-30. , -29.5, -29. , ...,  28.5,  29. ,  29.5],
#        ...,
#        [-30. , -29.5, -29. , ...,  28.5,  29. ,  29.5],
#        [-30. , -29.5, -29. , ...,  28.5,  29. ,  29.5],
#        [-30. , -29.5, -29. , ...,  28.5,  29. ,  29.5]])

# %%
Y
# Out:
# array([[-30. , -30. , -30. , ..., -30. , -30. , -30. ],
#        [-29.5, -29.5, -29.5, ..., -29.5, -29.5, -29.5],
#        [-29. , -29. , -29. , ..., -29. , -29. , -29. ],
#        ...,
#        [ 28.5,  28.5,  28.5, ...,  28.5,  28.5,  28.5],
#        [ 29. ,  29. ,  29. , ...,  29. ,  29. ,  29. ],
#        [ 29.5,  29.5,  29.5, ...,  29.5,  29.5,  29.5]])

# %%
Z
# Out:
# array([[-0.00982064, -0.0113957 , -0.01319036, ..., -0.01522953,
#         -0.01319036, -0.0113957 ],
#        [-0.0113957 , -0.01322338, -0.01530587, ..., -0.01767209,
#         -0.01530587, -0.01322338],
#        [-0.01319036, -0.01530587, -0.01771632, ..., -0.02045518,
#         -0.01771632, -0.01530587],
#        ...,
#        [-0.01200234, -0.01414685, -0.01660867, ...,  0.02918791,
#          0.03019517,  0.03085725],
#        [-0.01097235, -0.01288301, -0.01507265, ...,  0.01583738,
#          0.01709512,  0.01804782],
#        [-0.00988645, -0.01157475, -0.01350698, ...,  0.00702321,
#          0.0083816 ,  0.00947216]])

# %%
# Plot the 3D surface
ax.plot_surface(X, Y, Z, edgecolor='royalblue', lw=0.5, rstride=8, cstride=8,
                alpha=0.3)

# %%
# Plot projections of the contours for each dimension.  By choosing offsets
# that match the appropriate axes limits, the projected contours will sit on
# the 'walls' of the graph
ax.contourf(X, Y, Z, zdir='z', offset=-100, cmap='coolwarm')
ax.contourf(X, Y, Z, zdir='x', offset=-40, cmap='coolwarm')
ax.contourf(X, Y, Z, zdir='y', offset=40, cmap='coolwarm')

ax.set(xlim=(-40, 40), ylim=(-40, 40), zlim=(-100, 100),
       xlabel='X', ylabel='Y', zlabel='Z')

plt.show()
